# %%
'''
Nathan Able
M02 loops and conditionals
'''



#Section 4.1

#Import random function
import random
#set secret number to random int
secret = random.randint(1,10)

#Get guess from user
guess = int(input("Guess my secret number between 1 and 10? "))

#Check for match, >, or <
if guess == secret:
    print("Just right")
elif guess > secret:
    print ("too high, my number was "+ str(secret))
else:
    print("too low, my number was "+ str(secret))

#Section 4.2

#Define bool variable
small = False
green = False

#Get y/n from user
q1 = input("Guessing the secret item. Is it small? y/n: ")

#alter bool if yes
if q1 == "y":
    small = True
    print (small)

#get y/n from user
q2 = input("Is it green? y/n: ")

#alter bool if yes
if q2 == "y":
    green = True

    
#Compare bools to determine output
if small:
    if green:
        print("It's a pea")
    else:
        print("It's a cherry")
else:
    if green:
        print("It's a watermellon")
    else:
        print("it's a pumpkin")


#Section 6.1

#Create required list
myList = [3,2,1,0]

#Loop list
for i in myList:
    print (i)

#Section 6.2

#set required variables
guess_me = 7
number = 1

#Set loop with check parameters
while number <= guess_me:
    #If equal then done
    if number == guess_me:
        print("found it")
        break
    #Otherwise too low and increment
    else:
        print("too low")
        number += 1
    #If statement that will never be read because it is handled already in the while
    if number > guess_me:
        print ("opps")
        break

#Section 6.3

#Reset the required varibles
guess_me = 5
number = 0

#Set for loop to range of 10
for number in range(10):
    #If equal exit
    if number == guess_me:
        print("found it")
        break
    #Otherwise print low and loop
    else:
        print("too low")
    #Another iff statement that will not be read because it is handled by the first condition
    if number > guess_me:
        print("oops")
# Out:
# Guess my secret number between 1 and 10? 5
# too low, my number was 7
# Guessing the secret item. Is it small? y/n: y
# True
# Is it green? y/n: y
# It's a pea
# 3
# 2
# 1
# 0
# too low
# too low
# too low
# too low
# too low
# too low
# found it
# too low
# too low
# too low
# too low
# too low
# found it
